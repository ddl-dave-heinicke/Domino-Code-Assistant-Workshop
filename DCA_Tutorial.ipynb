# %%
# this code is generated by the Domino Code Assist toolbar button
import domino_code_assist as dca
dca.init()
# Out:
# Cannot show ipywidgets in text

# %%
import pandas as pd

df = pd.read_csv("/mnt/code/data/app_data.csv")
df
# Out:
#           HDF             datetime     CCGT  OIL  COAL  NUCLEAR  WIND   PS  \
# 0      FUELHH  2022-09-01 00:00:00  12833.0    0   880     4686  7031    0
# 1      FUELHH  2022-09-01 00:30:00  12611.0    0   895     4698  7011    0
# 2      FUELHH  2022-09-01 01:00:00  12417.0    0   823     4700  6928    0
# 3      FUELHH  2022-09-01 01:15:00      NaN    0   824     4699  6928    0
# 4      FUELHH  2022-09-01 01:18:00  12333.0    0   819     4698  7008    0
# ...       ...                  ...      ...  ...   ...      ...   ...  ...
# 10425  FUELHH  2023-04-06 04:00:00  10943.0    0   230     4127  6267    0
# 10426  FUELHH  2023-04-06 04:30:00  10929.0    0   230     4134  6387    0
# 10427  FUELHH  2023-04-06 05:00:00  11245.0    0   230     4137  6746    0
# 10428  FUELHH  2023-04-06 05:30:00  11670.0    0   230     4138  7078    0
# 10429  FUELHH  2023-04-06 06:00:00  12594.0    0   230     4133  7147  158
#
#        NPSHYD  OCGT  OTHER  INTFR  INTIRL  INTNED  INTEW  BIOMASS  INTEM
# 0          92     7  184.0      0       4       0      0     2061      0
# 1          92     9  167.0      0       0       0      0     2058      0
# 2          92     9  148.0      0       0       0      0     2057      0
# 3          92     9    NaN      0       0       0      0     2057      0
# 4          92     8    NaN      0       0       0      0     2057      0
# ...       ...   ...    ...    ...     ...     ...    ...      ...    ...
# 10425     134     0  192.0      0       0     206      0     2120      0
# 10426     134     0  188.0      0       0     214      0     2154      0
# 10427     172     0  142.0      0      72     222      8     2152      0
# 10428     209     0  136.0      0     146     214      0     2142      0
# 10429     335     0  308.0      0     192       0     68     2139     64
#
# [10430 rows x 17 columns]

# %%
df = df.loc[df["CCGT"].notna()]
df = df.loc[df["OTHER"].notna()]
df
# Out:
#           HDF             datetime     CCGT  OIL  COAL  NUCLEAR  WIND   PS  \
# 0      FUELHH  2022-09-01 00:00:00  12833.0    0   880     4686  7031    0
# 1      FUELHH  2022-09-01 00:30:00  12611.0    0   895     4698  7011    0
# 2      FUELHH  2022-09-01 01:00:00  12417.0    0   823     4700  6928    0
# 5      FUELHH  2022-09-01 01:30:00  12332.0    0   735     4698  6855    0
# 6      FUELHH  2022-09-01 02:00:00  12178.0    0   619     4698  6740    0
# ...       ...                  ...      ...  ...   ...      ...   ...  ...
# 10425  FUELHH  2023-04-06 04:00:00  10943.0    0   230     4127  6267    0
# 10426  FUELHH  2023-04-06 04:30:00  10929.0    0   230     4134  6387    0
# 10427  FUELHH  2023-04-06 05:00:00  11245.0    0   230     4137  6746    0
# 10428  FUELHH  2023-04-06 05:30:00  11670.0    0   230     4138  7078    0
# 10429  FUELHH  2023-04-06 06:00:00  12594.0    0   230     4133  7147  158
#
#        NPSHYD  OCGT  OTHER  INTFR  INTIRL  INTNED  INTEW  BIOMASS  INTEM
# 0          92     7  184.0      0       4       0      0     2061      0
# 1          92     9  167.0      0       0       0      0     2058      0
# 2          92     9  148.0      0       0       0      0     2057      0
# 5          92     9  145.0      0      14       0      0     2060      0
# 6          91     9  141.0      0      52       0      0     2066      0
# ...       ...   ...    ...    ...     ...     ...    ...      ...    ...
# 10425     134     0  192.0      0       0     206      0     2120      0
# 10426     134     0  188.0      0       0     214      0     2154      0
# 10427     172     0  142.0      0      72     222      8     2152      0
# 10428     209     0  136.0      0     146     214      0     2142      0
# 10429     335     0  308.0      0     192       0     68     2139     64
#
# [10426 rows x 17 columns]

# %%
import domino_code_assist as dca

df = dca.data.palmerpenguins()
df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# 1         3800.0  female  2007
# 2         3250.0  female  2007
# 3            NaN     NaN  2007
# 4         3450.0  female  2007
# ..           ...     ...   ...
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009
#
# [344 rows x 8 columns]

# %%
dfg = df.groupby(["island"]).agg(body_mass_g_sum=("body_mass_g", "sum")).reset_index()
dfg
# Out:
#       island  body_mass_g_sum
# 0     Biscoe         787575.0
# 1      Dream         460400.0
# 2  Torgersen         189025.0
